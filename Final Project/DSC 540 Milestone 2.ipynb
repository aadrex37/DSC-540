# %%
import pandas as pd
import numpy as np

# %%
##import and store csv file
df=pd.read_csv('Batting1.csv')
df
# Out:
#          playerID  yearID  stint teamID lgID   G   AB   R   H  2B  ...   RBI  \
# 0       abercda01    1871      1    TRO  NaN   1    4   0   0   0  ...   0.0
# 1        addybo01    1871      1    RC1  NaN  25  118  30  32   6  ...  13.0
# 2       allisar01    1871      1    CL1  NaN  29  137  28  40   4  ...  19.0
# 3       allisdo01    1871      1    WS3  NaN  27  133  28  44  10  ...  27.0
# 4       ansonca01    1871      1    RC1  NaN  25  120  29  39  11  ...  16.0
# ...           ...     ...    ...    ...  ...  ..  ...  ..  ..  ..  ...   ...
# 108784  zimmebr02    2020      1    BAL   AL   2    0   0   0   0  ...   0.0
# 108785  zimmejo02    2020      1    DET   AL   3    0   0   0   0  ...   0.0
# 108786  zimmeky01    2020      1    KCA   AL  16    0   0   0   0  ...   0.0
# 108787  zuberty01    2020      1    KCA   AL  23    0   0   0   0  ...   0.0
# 108788  zuninmi01    2020      1    TBA   AL  28   75   8  11   4  ...  10.0
#
# ...

# %%
##append df with a new column, batting average
df['AVG']=df['H']/df['AB']
df
# Out:
#          playerID  yearID  stint teamID lgID   G   AB   R   H  2B  ...   SB  \
# 0       abercda01    1871      1    TRO  NaN   1    4   0   0   0  ...  0.0
# 1        addybo01    1871      1    RC1  NaN  25  118  30  32   6  ...  8.0
# 2       allisar01    1871      1    CL1  NaN  29  137  28  40   4  ...  3.0
# 3       allisdo01    1871      1    WS3  NaN  27  133  28  44  10  ...  1.0
# 4       ansonca01    1871      1    RC1  NaN  25  120  29  39  11  ...  6.0
# ...           ...     ...    ...    ...  ...  ..  ...  ..  ..  ..  ...  ...
# 108784  zimmebr02    2020      1    BAL   AL   2    0   0   0   0  ...  0.0
# 108785  zimmejo02    2020      1    DET   AL   3    0   0   0   0  ...  0.0
# 108786  zimmeky01    2020      1    KCA   AL  16    0   0   0   0  ...  0.0
# 108787  zuberty01    2020      1    KCA   AL  23    0   0   0   0  ...  0.0
# 108788  zuninmi01    2020      1    TBA   AL  28   75   8  11   4  ...  0.0
#
# ...

# %%
##limit amount of entrys to specific year, 2016, and eliminates those who have less than 100 at bats 
df1= df[(df['yearID']==2016) & (df['AB']>=100)]
df1
# Out:
#          playerID  yearID  stint teamID lgID    G   AB   R    H  2B  ...   SB  \
# 101350  abreujo02    2016      1    CHA   AL  159  624  67  183  32  ...  0.0
# 101353  adamecr01    2016      1    COL   NL  121  225  25   49   7  ...  2.0
# 101355  adamsma01    2016      1    SLN   NL  118  297  37   74  18  ...  0.0
# 101359  ahmedni01    2016      1    ARI   NL   90  284  26   62   9  ...  5.0
# 101369  almonab01    2016      1    CLE   AL   67  182  24   48  20  ...  8.0
# ...           ...     ...    ...    ...  ...  ...  ...  ..  ...  ..  ...  ...
# 102815  yelicch01    2016      1    MIA   NL  155  578  78  172  38  ...  9.0
# 102820  youngch04    2016      1    BOS   AL   76  203  29   56  18  ...  4.0
# 102827  zimmery01    2016      1    WAS   NL  115  427  60   93  18  ...  4.0
# 102828  zobribe01    2016      1    CHN   NL  147  523  94  142  31  ...  6.0
# 102829  zuninmi01    2016      1    SEA   AL   55  164  16   34   7  ...  0.0
#
# ...

# %%
##removes all unnecessary columns
col=['playerID','teamID','AVG']
df2=df1[col]
df2
# Out:
#          playerID teamID       AVG
# 101350  abreujo02    CHA  0.293269
# 101353  adamecr01    COL  0.217778
# 101355  adamsma01    SLN  0.249158
# 101359  ahmedni01    ARI  0.218310
# 101369  almonab01    CLE  0.263736
# ...           ...    ...       ...
# 102815  yelicch01    MIA  0.297578
# 102820  youngch04    BOS  0.275862
# 102827  zimmery01    WAS  0.217799
# 102828  zobribe01    CHN  0.271511
# 102829  zuninmi01    SEA  0.207317
#
# [437 rows x 3 columns]

# %%
lead_avg=df2.sort_values(by='AVG',ascending=False)
lead_avg
##reorganizes dataframe in order of batting average from greatest batting average to least
# Out:
#          playerID teamID       AVG
# 102092  lemahdj01    COL  0.347826
# 102260  murphda08    WAS  0.346516
# 102721  turnetr01    WAS  0.342020
# 101374  altuvjo01    HOU  0.337500
# 102480  rivertj01    NYN  0.333333
# ...           ...    ...       ...
# 101842  gomesya01    CLE  0.167331
# 101724  eibnebr01    OAK  0.165138
# 102715  tuckepr01    HOU  0.164179
# 102458   reedaj01    HOU  0.163934
# 101598  coghlch01    OAK  0.145570
#
# [437 rows x 3 columns]

# %%
temp= lead_avg.reset_index()##resets index
lead=temp.reset_index()
lead
##resets index a second time creating a new column which we will make into our leaderboard
# Out:
#      level_0   index   playerID teamID       AVG
# 0          0  102092  lemahdj01    COL  0.347826
# 1          1  102260  murphda08    WAS  0.346516
# 2          2  102721  turnetr01    WAS  0.342020
# 3          3  101374  altuvjo01    HOU  0.337500
# 4          4  102480  rivertj01    NYN  0.333333
# ..       ...     ...        ...    ...       ...
# 432      432  101842  gomesya01    CLE  0.167331
# 433      433  101724  eibnebr01    OAK  0.165138
# 434      434  102715  tuckepr01    HOU  0.164179
# 435      435  102458   reedaj01    HOU  0.163934
# 436      436  101598  coghlch01    OAK  0.145570
#
# [437 rows x 5 columns]

# %%
lead['leaderboard'] = lead['level_0']+1 ##creates leaderboard
lead=lead.drop(['index','level_0'], axis=1) ##drop old original index and level_0 columns
lead
# Out:
#       playerID teamID       AVG  leaderboard
# 0    lemahdj01    COL  0.347826            1
# 1    murphda08    WAS  0.346516            2
# 2    turnetr01    WAS  0.342020            3
# 3    altuvjo01    HOU  0.337500            4
# 4    rivertj01    NYN  0.333333            5
# ..         ...    ...       ...          ...
# 432  gomesya01    CLE  0.167331          433
# 433  eibnebr01    OAK  0.165138          434
# 434  tuckepr01    HOU  0.164179          435
# 435   reedaj01    HOU  0.163934          436
# 436  coghlch01    OAK  0.145570          437
#
# [437 rows x 4 columns]

# %%
##limits df to top 50 in the leaderboard
leader_avg=lead[(lead['leaderboard']<=50)]
leader_avg
# Out:
#      playerID teamID       AVG  leaderboard
# 0   lemahdj01    COL  0.347826            1
# 1   murphda08    WAS  0.346516            2
# 2   turnetr01    WAS  0.342020            3
# 3   altuvjo01    HOU  0.337500            4
# 4   rivertj01    NYN  0.333333            5
# 5   vottojo01    CIN  0.325540            6
# 6   perazjo01    CIN  0.323651            7
# 7   blackch02    COL  0.323529            8
# 8   segurje01    ARI  0.318681            9
# 9   bettsmo01    BOS  0.318452           10
# 10  pedrodu01    BOS  0.317536           11
# 11  cabremi01    DET  0.315966           12
# 12   dahlda01    COL  0.315315           13
# 13  maybica01    DET  0.315186           14
# 14  troutmi01    LAA  0.315118           15
# 15  ortizda01    BOS  0.314711           16
# 16  tolesan01    LAN  0.314286           17
# 17  ramirjo01    CLE  0.311504           18
# 18  martest01    PIT  0.310838           19
# 19   leonsa01    BOS  0.309524           20
# ...

# %%
df3=leader_avg.set_index(['leaderboard'])##sets index to leaderboard
df3
# Out:
#               playerID teamID       AVG
# leaderboard
# 1            lemahdj01    COL  0.347826
# 2            murphda08    WAS  0.346516
# 3            turnetr01    WAS  0.342020
# 4            altuvjo01    HOU  0.337500
# 5            rivertj01    NYN  0.333333
# 6            vottojo01    CIN  0.325540
# 7            perazjo01    CIN  0.323651
# 8            blackch02    COL  0.323529
# 9            segurje01    ARI  0.318681
# 10           bettsmo01    BOS  0.318452
# 11           pedrodu01    BOS  0.317536
# 12           cabremi01    DET  0.315966
# 13            dahlda01    COL  0.315315
# 14           maybica01    DET  0.315186
# 15           troutmi01    LAA  0.315118
# 16           ortizda01    BOS  0.314711
# 17           tolesan01    LAN  0.314286
# 18           ramirjo01    CLE  0.311504
# 19           martest01    PIT  0.310838
# 20            leonsa01    BOS  0.309524
# 21           pearcst01    TBA  0.308824
# 22           seageco01    LAN  0.307815
# ...

# %%
teams= df3.sort_values('teamID')
teams
# Out:
#               playerID teamID       AVG
# leaderboard
# 47           goldspa01    ARI  0.297064
# 9            segurje01    ARI  0.318681
# 34           freemfr01    ATL  0.302207
# 33           swansda01    ATL  0.302326
# 36             kimhy01    BAL  0.301639
# 10           bettsmo01    BOS  0.318452
# 11           pedrodu01    BOS  0.317536
# 20            leonsa01    BOS  0.309524
# 16           ortizda01    BOS  0.314711
# 50           cabreme01    CHA  0.296108
# 6            vottojo01    CIN  0.325540
# 7            perazjo01    CIN  0.323651
# 38           lindofr01    CLE  0.301325
# 18           ramirjo01    CLE  0.311504
# 44           gonzaca01    COL  0.297945
# 1            lemahdj01    COL  0.347826
# 8            blackch02    COL  0.323529
# 13            dahlda01    COL  0.315315
# 12           cabremi01    DET  0.315966
# 25           martijd02    DET  0.306522
# 14           maybica01    DET  0.315186
# 4            altuvjo01    HOU  0.337500
# ...

# %%
df3.to_csv("mlst2.csv")
